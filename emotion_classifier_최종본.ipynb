# %%
import numpy as np
import cv2
from keras.models import load_model
import dlib
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class face_exp():
    def __init__(self):
        self.model = load_model("/content/drive/Shareddrives/인지프/data/cv/model-3.h5")
       
    def predict(self,filepath):
        emotions = ('분노', '두려움', '행복함', '슬픔', '놀람', '보통')
        img=cv2.imread(filepath)
        img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #img = cv2.resize(img, (48,48))
        face_detector=dlib.get_frontal_face_detector()
        faces=face_detector(img)
        if (len(faces) == 0):
            return "Not Recognized."
        for f in faces:
            crop=img[f.top():f.bottom(),f.left():f.right()]
        
        print('crop shape : {}'.format(crop.shape))
        crop = cv2.resize(crop, (48, 48))
        plt.imshow(crop)
        plt.show()
        output1 = emotions[np.argmax(self.model.predict(crop.reshape((1,48,48,1))), axis=-1)[0]]
        print('face expression output : {}'.format(output1))
        output2 = self.model.predict(crop.reshape((1,48,48,1)))
        print('Percentage Each expression : {}'.format(output2*100))
        output2 = output2.tolist()
        print(output2)
        
        list_percentage = []
        for i in range(5):
          lis = []
          lis.append(emotions[i])
          lis.append(output2[0][i])
          list_percentage.append(lis)

        return list_percentage

# %%
classifier = face_exp()
print('분노', '두려움', '행복함', '슬픔', '놀람', '보통')
print(' ')
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/test2.png'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/[원천]EMOIMG_중립_VALID/01a6c69e76d729863380b8391d780e53070cf8629ad9ffd5d06826551271fe74_남_30_중립_오락&공연시설_20201207110400-005-001.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/[원천]EMOIMG_중립_VALID/03f84d01e35a8d2beed4c9467a82c212daa05809d0bc980865765fe6b0f2e9cd_남_20_중립_도심 환경_20210201172549-008-005.jpg'))
#print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/[원천]EMOIMG_중립_VALID/0b33836b914f544c31e3a642ccccbb94114040537440b4df3b9250d025fc39a5_여_20_중립_숙박 및 거주공간_20210209152239-010-033.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/[원천]EMOIMG_중립_VALID/18b7be47586fa292f18031e3cc12a5b986baed03408c6734380cdc805c4df307_여_30_중립_오락&공연시설_20201205224434-005-005.jpg'))

print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/기쁨.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/기쁨3.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/기쁨2.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/cv/기쁨4.jpg'))

print(classifier.predict('/content/drive/Shareddrives/인지프/data/[원천]EMOIMG_슬픔_VALID/01a6c69e76d729863380b8391d780e53070cf8629ad9ffd5d06826551271fe74_남_30_슬픔_도심 환경_20201207105401-008-017.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/[원천]EMOIMG_슬픔_VALID/064c9650db76c75f0d8cdc31898eb031aece3cd1e7825531d841730daefade73_여_20_슬픔_공공시설&종교&의료시설_20201206202724-001-005.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/[원천]EMOIMG_슬픔_VALID/064c9650db76c75f0d8cdc31898eb031aece3cd1e7825531d841730daefade73_여_20_슬픔_상업시설&점포&시장_20201206202744-003-029.jpg'))
print(classifier.predict('/content/drive/Shareddrives/인지프/data/[원천]EMOIMG_슬픔_VALID/088fed93316d43566be2fd844159eabf77e3025bf465076921ef38e9726bd8c1_남_20_슬픔_스포츠 관람 및 레저시설_20201209143329-004-006.jpg'))
# Out:
# 분노 두려움 행복함 슬픔 놀람 보통
#
# crop shape : (179, 179)
# 1/1 [==============================] - 0s 194ms/step
# face expression output : 슬픔
# 1/1 [==============================] - 0s 31ms/step
# Percentage Each expression : [[4.5649233e-01 1.2687594e+00 5.3382796e-01 9.0208954e+01 7.5013666e+00
#   3.0590460e-02]]
# [[0.004564923234283924, 0.012687593698501587, 0.005338279530405998, 0.902089536190033, 0.075013667345047, 0.0003059045993722975]]
# [['분노', 0.004564923234283924], ['두려움', 0.012687593698501587], ['행복함', 0.005338279530405998], ['슬픔', 0.902089536190033], ['놀람', 0.075013667345047]]
# crop shape : (770, 770)
# 1/1 [==============================] - 0s 33ms/step
# face expression output : 슬픔
# 1/1 [==============================] - 0s 34ms/step
# Percentage Each expression : [[ 8.173533    7.8548746   0.25317943 71.14855    11.25704     1.3128179 ]]
# [[0.08173533529043198, 0.07854874432086945, 0.0025317943654954433, 0.7114855051040649, 0.11257040500640869, 0.013128179125487804]]
# ...
